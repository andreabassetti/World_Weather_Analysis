# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=638e60cb34fc106be7d2abdc7970aa54

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_weather = city_weather["weather"][0]["description"]

        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Weather": current_weather})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | clyde river
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | salalah
# Processing Record 8 of Set 1 | shingu
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | harper
# Processing Record 14 of Set 1 | san patricio
# Processing Record 15 of Set 1 | bambous virieux
# Processing Record 16 of Set 1 | dongsheng
# Processing Record 17 of Set 1 | altay
# Processing Record 18 of Set 1 | ribeira grande
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | ksenyevka
# City not found. Skipping...
# Processing Record 23 of Set 1 | saint-augustin
# Processing Record 24 of Set 1 | portland
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | coquimbo
# Processing Record 27 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | kargat
# Processing Record 30 of Set 1 | vila velha
# Processing Record 31 of Set 1 | barao de melgaco
# Processing Record 32 of Set 1 | yumen
# Processing Record 33 of Set 1 | klaksvik
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | loubomo
# Processing Record 36 of Set 1 | cap malheureux
# Processing Record 37 of Set 1 | moorhead
# Processing Record 38 of Set 1 | ahipara
# Processing Record 39 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 1 | vila franca do campo
# Processing Record 41 of Set 1 | kyren
# Processing Record 42 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 43 of Set 1 | bloomingdale
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | westport
# Processing Record 46 of Set 1 | virden
# Processing Record 47 of Set 1 | taldan
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | emerald
# Processing Record 3 of Set 2 | tura
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | cherskiy
# Processing Record 6 of Set 2 | san cristobal
# Processing Record 7 of Set 2 | richards bay
# Processing Record 8 of Set 2 | georgetown
# Processing Record 9 of Set 2 | komsomolskiy
# Processing Record 10 of Set 2 | palmer
# Processing Record 11 of Set 2 | ponta do sol
# Processing Record 12 of Set 2 | lagoa
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | olinda
# Processing Record 15 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 2 | abong mbang
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | guerrero
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | provideniya
# Processing Record 21 of Set 2 | gazni
# City not found. Skipping...
# Processing Record 22 of Set 2 | tukrah
# Processing Record 23 of Set 2 | kolokani
# Processing Record 24 of Set 2 | nanortalik
# Processing Record 25 of Set 2 | la ronge
# Processing Record 26 of Set 2 | bolitoc
# Processing Record 27 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 2 | bambanglipuro
# Processing Record 29 of Set 2 | smithers
# Processing Record 30 of Set 2 | cabo san lucas
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | nikolskoye
# Processing Record 33 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 2 | bluff
# Processing Record 35 of Set 2 | pevek
# Processing Record 36 of Set 2 | marrakesh
# Processing Record 37 of Set 2 | paracuru
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | kodiak
# Processing Record 40 of Set 2 | sao filipe
# Processing Record 41 of Set 2 | north bend
# Processing Record 42 of Set 2 | noumea
# Processing Record 43 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 44 of Set 2 | mocajuba
# Processing Record 45 of Set 2 | bethel
# Processing Record 46 of Set 2 | trois-pistoles
# City not found. Skipping...
# Processing Record 47 of Set 2 | kozhanka
# Processing Record 48 of Set 2 | dong hoi
# Processing Record 49 of Set 2 | geraldton
# Processing Record 50 of Set 2 | quang ngai
# Processing Record 1 of Set 3 | peniche
# Processing Record 2 of Set 3 | upernavik
# Processing Record 3 of Set 3 | port alfred
# Processing Record 4 of Set 3 | husavik
# Processing Record 5 of Set 3 | mitsamiouli
# Processing Record 6 of Set 3 | maamba
# Processing Record 7 of Set 3 | margate
# Processing Record 8 of Set 3 | beisfjord
# Processing Record 9 of Set 3 | tsienyane
# City not found. Skipping...
# Processing Record 10 of Set 3 | lavrentiya
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | dimitrovgrad
# Processing Record 13 of Set 3 | chuy
# Processing Record 14 of Set 3 | ubatuba
# Processing Record 15 of Set 3 | kuryk
# Processing Record 16 of Set 3 | wajima
# Processing Record 17 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 3 | mukhen
# Processing Record 19 of Set 3 | shalyhyne
# Processing Record 20 of Set 3 | paita
# Processing Record 21 of Set 3 | taoudenni
# Processing Record 22 of Set 3 | bredasdorp
# Processing Record 23 of Set 3 | pauini
# Processing Record 24 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 3 | laguna
# Processing Record 26 of Set 3 | gangotri
# City not found. Skipping...
# Processing Record 27 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 3 | hermanus
# Processing Record 29 of Set 3 | cape town
# Processing Record 30 of Set 3 | fortuna
# Processing Record 31 of Set 3 | tual
# Processing Record 32 of Set 3 | havre-saint-pierre
# Processing Record 33 of Set 3 | aleksandrov gay
# Processing Record 34 of Set 3 | barmer
# Processing Record 35 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 3 | chara
# Processing Record 37 of Set 3 | new norfolk
# Processing Record 38 of Set 3 | puerto el triunfo
# Processing Record 39 of Set 3 | san carlos de bariloche
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | luderitz
# Processing Record 42 of Set 3 | touros
# Processing Record 43 of Set 3 | villamontes
# Processing Record 44 of Set 3 | mahanoro
# Processing Record 45 of Set 3 | okha
# Processing Record 46 of Set 3 | san francisco
# Processing Record 47 of Set 3 | bagdarin
# Processing Record 48 of Set 3 | catuday
# Processing Record 49 of Set 3 | dehloran
# Processing Record 50 of Set 3 | jijiga
# Processing Record 1 of Set 4 | gohana
# Processing Record 2 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 4 | biltine
# Processing Record 4 of Set 4 | faanui
# Processing Record 5 of Set 4 | zyryanka
# Processing Record 6 of Set 4 | yingkou
# Processing Record 7 of Set 4 | santiago
# Processing Record 8 of Set 4 | zambezi
# Processing Record 9 of Set 4 | muros
# Processing Record 10 of Set 4 | pangnirtung
# Processing Record 11 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 4 | marawi
# Processing Record 13 of Set 4 | torbay
# Processing Record 14 of Set 4 | half moon bay
# Processing Record 15 of Set 4 | tiksi
# Processing Record 16 of Set 4 | acapulco
# Processing Record 17 of Set 4 | comodoro rivadavia
# Processing Record 18 of Set 4 | katsuura
# Processing Record 19 of Set 4 | clifton
# Processing Record 20 of Set 4 | raichur
# Processing Record 21 of Set 4 | katherine
# Processing Record 22 of Set 4 | berea
# Processing Record 23 of Set 4 | necochea
# Processing Record 24 of Set 4 | alofi
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | waddan
# Processing Record 27 of Set 4 | yellowknife
# Processing Record 28 of Set 4 | turayf
# Processing Record 29 of Set 4 | esil
# Processing Record 30 of Set 4 | kieta
# Processing Record 31 of Set 4 | mount isa
# Processing Record 32 of Set 4 | fez
# Processing Record 33 of Set 4 | port lincoln
# Processing Record 34 of Set 4 | severo-kurilsk
# Processing Record 35 of Set 4 | jaguaribe
# Processing Record 36 of Set 4 | saint-philippe
# Processing Record 37 of Set 4 | broken hill
# Processing Record 38 of Set 4 | qandala
# Processing Record 39 of Set 4 | mbarara
# Processing Record 40 of Set 4 | saldanha
# Processing Record 41 of Set 4 | cozumel
# Processing Record 42 of Set 4 | mar del plata
# Processing Record 43 of Set 4 | nikolsk
# Processing Record 44 of Set 4 | ancud
# Processing Record 45 of Set 4 | luganville
# Processing Record 46 of Set 4 | saskylakh
# Processing Record 47 of Set 4 | ourossogui
# Processing Record 48 of Set 4 | naryan-mar
# Processing Record 49 of Set 4 | petrozavodsk
# Processing Record 50 of Set 4 | lydenburg
# Processing Record 1 of Set 5 | dhidhdhoo
# Processing Record 2 of Set 5 | cedar city
# Processing Record 3 of Set 5 | paris
# Processing Record 4 of Set 5 | pampa
# Processing Record 5 of Set 5 | bonthe
# Processing Record 6 of Set 5 | yar-sale
# Processing Record 7 of Set 5 | hambantota
# Processing Record 8 of Set 5 | kaeo
# Processing Record 9 of Set 5 | seoul
# Processing Record 10 of Set 5 | iquitos
# Processing Record 11 of Set 5 | montilla
# Processing Record 12 of Set 5 | presidencia roque saenz pena
# Processing Record 13 of Set 5 | maniitsoq
# Processing Record 14 of Set 5 | sorland
# Processing Record 15 of Set 5 | longyearbyen
# Processing Record 16 of Set 5 | taltal
# Processing Record 17 of Set 5 | constitucion
# Processing Record 18 of Set 5 | roblin
# Processing Record 19 of Set 5 | nueva loja
# Processing Record 20 of Set 5 | odweyne
# Processing Record 21 of Set 5 | fort nelson
# Processing Record 22 of Set 5 | kaduna
# Processing Record 23 of Set 5 | the valley
# Processing Record 24 of Set 5 | pergamino
# Processing Record 25 of Set 5 | ca mau
# Processing Record 26 of Set 5 | vardo
# Processing Record 27 of Set 5 | mabaruma
# Processing Record 28 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 5 | arraial do cabo
# Processing Record 30 of Set 5 | ewa beach
# Processing Record 31 of Set 5 | wilmington island
# Processing Record 32 of Set 5 | strezhevoy
# Processing Record 33 of Set 5 | esperance
# Processing Record 34 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 5 | baruun-urt
# Processing Record 36 of Set 5 | dikson
# Processing Record 37 of Set 5 | port-cartier
# Processing Record 38 of Set 5 | homer
# Processing Record 39 of Set 5 | cortes
# Processing Record 40 of Set 5 | oussouye
# Processing Record 41 of Set 5 | lorengau
# Processing Record 42 of Set 5 | namibe
# Processing Record 43 of Set 5 | sibolga
# Processing Record 44 of Set 5 | sudislavl
# Processing Record 45 of Set 5 | fortuna foothills
# Processing Record 46 of Set 5 | talnakh
# Processing Record 47 of Set 5 | maues
# Processing Record 48 of Set 5 | sorong
# Processing Record 49 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 5 | codrington
# Processing Record 1 of Set 6 | albertville
# Processing Record 2 of Set 6 | alto araguaia
# Processing Record 3 of Set 6 | georgiyevka
# Processing Record 4 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 6 | hervey bay
# Processing Record 6 of Set 6 | nome
# Processing Record 7 of Set 6 | berlevag
# Processing Record 8 of Set 6 | penzance
# Processing Record 9 of Set 6 | burica
# City not found. Skipping...
# Processing Record 10 of Set 6 | batagay-alyta
# Processing Record 11 of Set 6 | bilma
# Processing Record 12 of Set 6 | bathsheba
# Processing Record 13 of Set 6 | bitung
# Processing Record 14 of Set 6 | la victoria
# Processing Record 15 of Set 6 | tarakan
# Processing Record 16 of Set 6 | vostok
# Processing Record 17 of Set 6 | rakkestad
# Processing Record 18 of Set 6 | kattivakkam
# Processing Record 19 of Set 6 | satun
# Processing Record 20 of Set 6 | springbok
# Processing Record 21 of Set 6 | camacha
# Processing Record 22 of Set 6 | varna
# Processing Record 23 of Set 6 | okhotsk
# Processing Record 24 of Set 6 | castro
# Processing Record 25 of Set 6 | guerrero negro
# Processing Record 26 of Set 6 | cervo
# Processing Record 27 of Set 6 | tiarei
# Processing Record 28 of Set 6 | ampanihy
# Processing Record 29 of Set 6 | manokwari
# Processing Record 30 of Set 6 | koudougou
# Processing Record 31 of Set 6 | ornskoldsvik
# Processing Record 32 of Set 6 | cayenne
# Processing Record 33 of Set 6 | lomovka
# Processing Record 34 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 6 | kavieng
# Processing Record 36 of Set 6 | guangshui
# Processing Record 37 of Set 6 | gizo
# Processing Record 38 of Set 6 | kosh-agach
# Processing Record 39 of Set 6 | biak
# Processing Record 40 of Set 6 | tucurui
# Processing Record 41 of Set 6 | mingyue
# Processing Record 42 of Set 6 | fairbanks
# Processing Record 43 of Set 6 | ilulissat
# Processing Record 44 of Set 6 | payyannur
# Processing Record 45 of Set 6 | turbiv
# Processing Record 46 of Set 6 | elat
# Processing Record 47 of Set 6 | wesselsbron
# Processing Record 48 of Set 6 | clarence town
# Processing Record 49 of Set 6 | suleja
# Processing Record 50 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 7 | inirida
# Processing Record 2 of Set 7 | seydisehir
# Processing Record 3 of Set 7 | tuatapere
# Processing Record 4 of Set 7 | mahebourg
# Processing Record 5 of Set 7 | moerai
# Processing Record 6 of Set 7 | melilla
# Processing Record 7 of Set 7 | caravelas
# Processing Record 8 of Set 7 | mount gambier
# Processing Record 9 of Set 7 | cidreira
# Processing Record 10 of Set 7 | pachino
# Processing Record 11 of Set 7 | faro
# Processing Record 12 of Set 7 | atar
# Processing Record 13 of Set 7 | parras
# City not found. Skipping...
# Processing Record 14 of Set 7 | chokurdakh
# Processing Record 15 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 7 | puerto leguizamo
# Processing Record 17 of Set 7 | ust-kishert
# Processing Record 18 of Set 7 | andarab
# City not found. Skipping...
# Processing Record 19 of Set 7 | azimur
# City not found. Skipping...
# Processing Record 20 of Set 7 | aklavik
# Processing Record 21 of Set 7 | yian
# City not found. Skipping...
# Processing Record 22 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 7 | beringovskiy
# Processing Record 24 of Set 7 | cockburn town
# Processing Record 25 of Set 7 | victoria
# Processing Record 26 of Set 7 | hithadhoo
# Processing Record 27 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 7 | santa isabel do rio negro
# Processing Record 29 of Set 7 | padang
# Processing Record 30 of Set 7 | havelock
# Processing Record 31 of Set 7 | puerto gaitan
# Processing Record 32 of Set 7 | tieling
# Processing Record 33 of Set 7 | belaya gora
# Processing Record 34 of Set 7 | ouadda
# Processing Record 35 of Set 7 | marzuq
# Processing Record 36 of Set 7 | olafsvik
# Processing Record 37 of Set 7 | saint-pierre
# Processing Record 38 of Set 7 | acarau
# Processing Record 39 of Set 7 | kiama
# Processing Record 40 of Set 7 | matagami
# Processing Record 41 of Set 7 | sananduva
# Processing Record 42 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 7 | calabar
# Processing Record 44 of Set 7 | barinas
# Processing Record 45 of Set 7 | broome
# Processing Record 46 of Set 7 | badarganj
# Processing Record 47 of Set 7 | san rafael
# Processing Record 48 of Set 7 | aleysk
# Processing Record 49 of Set 7 | omboue
# Processing Record 50 of Set 7 | kazerun
# Processing Record 1 of Set 8 | hokitika
# Processing Record 2 of Set 8 | melbourne
# Processing Record 3 of Set 8 | marshall
# Processing Record 4 of Set 8 | omsukchan
# Processing Record 5 of Set 8 | ternate
# Processing Record 6 of Set 8 | lyaskelya
# Processing Record 7 of Set 8 | dorfen
# Processing Record 8 of Set 8 | kabompo
# Processing Record 9 of Set 8 | nancha
# Processing Record 10 of Set 8 | coihaique
# Processing Record 11 of Set 8 | leningradskiy
# Processing Record 12 of Set 8 | leshukonskoye
# Processing Record 13 of Set 8 | sanghar
# Processing Record 14 of Set 8 | ovsyanka
# Processing Record 15 of Set 8 | iracoubo
# Processing Record 16 of Set 8 | kumano
# Processing Record 17 of Set 8 | poum
# Processing Record 18 of Set 8 | praia da vitoria
# Processing Record 19 of Set 8 | nortelandia
# Processing Record 20 of Set 8 | ust-tsilma
# Processing Record 21 of Set 8 | bluffton
# Processing Record 22 of Set 8 | kemin
# Processing Record 23 of Set 8 | sao felix do xingu
# Processing Record 24 of Set 8 | mporokoso
# Processing Record 25 of Set 8 | aswan
# Processing Record 26 of Set 8 | russkaya polyana
# Processing Record 27 of Set 8 | mogadishu
# Processing Record 28 of Set 8 | santa vitoria do palmar
# Processing Record 29 of Set 8 | samarai
# Processing Record 30 of Set 8 | iqaluit
# Processing Record 31 of Set 8 | starodub
# Processing Record 32 of Set 8 | karratha
# Processing Record 33 of Set 8 | cherdyn
# Processing Record 34 of Set 8 | hualmay
# Processing Record 35 of Set 8 | manzhouli
# Processing Record 36 of Set 8 | saint-joseph
# Processing Record 37 of Set 8 | zaokskiy
# Processing Record 38 of Set 8 | neyyattinkara
# Processing Record 39 of Set 8 | point pedro
# Processing Record 40 of Set 8 | zhigansk
# Processing Record 41 of Set 8 | kirakira
# Processing Record 42 of Set 8 | sitka
# Processing Record 43 of Set 8 | urengoy
# Processing Record 44 of Set 8 | cortez
# Processing Record 45 of Set 8 | lebu
# Processing Record 46 of Set 8 | carndonagh
# Processing Record 47 of Set 8 | saint george
# Processing Record 48 of Set 8 | korla
# Processing Record 49 of Set 8 | monrovia
# Processing Record 50 of Set 8 | talakan
# Processing Record 1 of Set 9 | celestun
# Processing Record 2 of Set 9 | aksay
# Processing Record 3 of Set 9 | dingle
# Processing Record 4 of Set 9 | lima
# Processing Record 5 of Set 9 | farrukhnagar
# Processing Record 6 of Set 9 | crestview
# Processing Record 7 of Set 9 | kilindoni
# Processing Record 8 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 9 | ostersund
# Processing Record 10 of Set 9 | goderich
# Processing Record 11 of Set 9 | peleduy
# Processing Record 12 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 13 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 9 | carutapera
# Processing Record 15 of Set 9 | sakakah
# Processing Record 16 of Set 9 | lasa
# Processing Record 17 of Set 9 | majene
# Processing Record 18 of Set 9 | pangody
# Processing Record 19 of Set 9 | tumarbong
# Processing Record 20 of Set 9 | vila
# Processing Record 21 of Set 9 | flinders
# Processing Record 22 of Set 9 | taperoa
# Processing Record 23 of Set 9 | atambua
# Processing Record 24 of Set 9 | brae
# Processing Record 25 of Set 9 | talara
# Processing Record 26 of Set 9 | kenai
# Processing Record 27 of Set 9 | kaitangata
# Processing Record 28 of Set 9 | kruisfontein
# Processing Record 29 of Set 9 | hasaki
# Processing Record 30 of Set 9 | saint-gabriel
# Processing Record 31 of Set 9 | khani
# Processing Record 32 of Set 9 | mae sai
# Processing Record 33 of Set 9 | russell
# Processing Record 34 of Set 9 | desnogorsk
# Processing Record 35 of Set 9 | svetlaya
# Processing Record 36 of Set 9 | waitati
# Processing Record 37 of Set 9 | srednekolymsk
# Processing Record 38 of Set 9 | casablanca
# Processing Record 39 of Set 9 | japura
# Processing Record 40 of Set 9 | barra do bugres
# Processing Record 41 of Set 9 | jacareacanga
# Processing Record 42 of Set 9 | sola
# Processing Record 43 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 44 of Set 9 | sambava
# Processing Record 45 of Set 9 | bengkulu
# Processing Record 46 of Set 9 | faya
# Processing Record 47 of Set 9 | arman
# Processing Record 48 of Set 9 | asmara
# Processing Record 49 of Set 9 | murgab
# Processing Record 50 of Set 9 | porosozero
# Processing Record 1 of Set 10 | manubul
# Processing Record 2 of Set 10 | lamar
# Processing Record 3 of Set 10 | huarmey
# Processing Record 4 of Set 10 | weligama
# Processing Record 5 of Set 10 | malanje
# Processing Record 6 of Set 10 | narsaq
# Processing Record 7 of Set 10 | krasnoselkup
# Processing Record 8 of Set 10 | dundee
# Processing Record 9 of Set 10 | domoni
# Processing Record 10 of Set 10 | waingapu
# Processing Record 11 of Set 10 | basco
# Processing Record 12 of Set 10 | oranjemund
# Processing Record 13 of Set 10 | dawei
# Processing Record 14 of Set 10 | ta khmau
# Processing Record 15 of Set 10 | lompoc
# Processing Record 16 of Set 10 | baherden
# Processing Record 17 of Set 10 | anjar
# Processing Record 18 of Set 10 | reconquista
# Processing Record 19 of Set 10 | sembe
# Processing Record 20 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 10 | emmett
# Processing Record 22 of Set 10 | amapa
# Processing Record 23 of Set 10 | puri
# Processing Record 24 of Set 10 | norman wells
# Processing Record 25 of Set 10 | najran
# Processing Record 26 of Set 10 | deputatskiy
# Processing Record 27 of Set 10 | tigil
# Processing Record 28 of Set 10 | raipur
# Processing Record 29 of Set 10 | ayr
# Processing Record 30 of Set 10 | batagay
# Processing Record 31 of Set 10 | praia
# Processing Record 32 of Set 10 | entre rios
# Processing Record 33 of Set 10 | klyuchi
# Processing Record 34 of Set 10 | the pas
# Processing Record 35 of Set 10 | atherton
# Processing Record 36 of Set 10 | bhadrapur
# Processing Record 37 of Set 10 | mangaluru
# Processing Record 38 of Set 10 | alice springs
# Processing Record 39 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 10 | adrar
# Processing Record 41 of Set 10 | hobyo
# Processing Record 42 of Set 10 | te anau
# Processing Record 43 of Set 10 | ponta delgada
# Processing Record 44 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 10 | busayra
# Processing Record 46 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 47 of Set 10 | valparaiso
# Processing Record 48 of Set 10 | ahuimanu
# Processing Record 49 of Set 10 | armizonskoye
# Processing Record 50 of Set 10 | riberalta
# Processing Record 1 of Set 11 | straoane
# Processing Record 2 of Set 11 | san jose
# Processing Record 3 of Set 11 | juneau
# Processing Record 4 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 5 of Set 11 | doka
# Processing Record 6 of Set 11 | tabas
# Processing Record 7 of Set 11 | badajoz
# Processing Record 8 of Set 11 | ketchikan
# Processing Record 9 of Set 11 | sesheke
# Processing Record 10 of Set 11 | egvekinot
# Processing Record 11 of Set 11 | malinovka
# Processing Record 12 of Set 11 | gamba
# Processing Record 13 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 11 | gharo
# Processing Record 15 of Set 11 | pacific grove
# Processing Record 16 of Set 11 | ballina
# Processing Record 17 of Set 11 | kikwit
# Processing Record 18 of Set 11 | hofn
# Processing Record 19 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 20 of Set 11 | tsurugi
# Processing Record 21 of Set 11 | mao
# Processing Record 22 of Set 11 | san vicente
# Processing Record 23 of Set 11 | cholet
# Processing Record 24 of Set 11 | colares
# Processing Record 25 of Set 11 | mucurapo
# Processing Record 26 of Set 11 | fallon
# Processing Record 27 of Set 11 | fare
# Processing Record 28 of Set 11 | askiz
# Processing Record 29 of Set 11 | khash
# Processing Record 30 of Set 11 | zaozerne
# Processing Record 31 of Set 11 | rockingham
# Processing Record 32 of Set 11 | wausau
# Processing Record 33 of Set 11 | khanpur
# Processing Record 34 of Set 11 | lazaro cardenas
# Processing Record 35 of Set 11 | yantal
# Processing Record 36 of Set 11 | phan thiet
# Processing Record 37 of Set 11 | viedma
# Processing Record 38 of Set 11 | aksu
# Processing Record 39 of Set 11 | kaohsiung
# Processing Record 40 of Set 11 | kyzyl-mazhalyk
# Processing Record 41 of Set 11 | sapulpa
# Processing Record 42 of Set 11 | salinas
# Processing Record 43 of Set 11 | semey
# Processing Record 44 of Set 11 | maragogi
# Processing Record 45 of Set 11 | pittsfield
# Processing Record 46 of Set 11 | bereda
# Processing Record 47 of Set 11 | san onofre
# Processing Record 48 of Set 11 | nhulunbuy
# Processing Record 49 of Set 11 | ulladulla
# Processing Record 50 of Set 11 | lilongwe
# Processing Record 1 of Set 12 | kardamaina
# Processing Record 2 of Set 12 | dakoro
# Processing Record 3 of Set 12 | raudeberg
# Processing Record 4 of Set 12 | shelburne
# Processing Record 5 of Set 12 | nyanza
# Processing Record 6 of Set 12 | qasigiannguit
# Processing Record 7 of Set 12 | bac lieu
# Processing Record 8 of Set 12 | rudnogorsk
# Processing Record 9 of Set 12 | varhaug
# Processing Record 10 of Set 12 | pamekasan
# Processing Record 11 of Set 12 | khorixas
# Processing Record 12 of Set 12 | tasca
# Processing Record 13 of Set 12 | lac du bonnet
# Processing Record 14 of Set 12 | beloha
# Processing Record 15 of Set 12 | kloulklubed
# Processing Record 16 of Set 12 | albanel
# Processing Record 17 of Set 12 | baykit
# Processing Record 18 of Set 12 | launceston
# Processing Record 19 of Set 12 | san juan
# Processing Record 20 of Set 12 | kuusamo
# Processing Record 21 of Set 12 | huilong
# Processing Record 22 of Set 12 | grand-lahou
# Processing Record 23 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 12 | daru
# Processing Record 25 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 26 of Set 12 | pochutla
# Processing Record 27 of Set 12 | vestmannaeyjar
# Processing Record 28 of Set 12 | araioses
# Processing Record 29 of Set 12 | valdivia
# Processing Record 30 of Set 12 | naral
# City not found. Skipping...
# Processing Record 31 of Set 12 | chapais
# Processing Record 32 of Set 12 | chegdomyn
# Processing Record 33 of Set 12 | corinto
# Processing Record 34 of Set 12 | kozlovo
# Processing Record 35 of Set 12 | ulloa
# Processing Record 36 of Set 12 | rexburg
# Processing Record 37 of Set 12 | waipawa
# Processing Record 38 of Set 12 | xiaoweizhai
# Processing Record 39 of Set 12 | dong xoai
# Processing Record 40 of Set 12 | grindavik
# Processing Record 41 of Set 12 | verkhnyaya inta
# Processing Record 42 of Set 12 | warrnambool
# Processing Record 43 of Set 12 | murupara
# Processing Record 44 of Set 12 | tunceli
# Processing Record 45 of Set 12 | kabalo
# Processing Record 46 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 47 of Set 12 | bonavista
# Processing Record 48 of Set 12 | west wendover
# Processing Record 49 of Set 12 | oranjestad
# Processing Record 50 of Set 12 | paciran
# Processing Record 1 of Set 13 | carlos chagas
# Processing Record 2 of Set 13 | gorontalo
# Processing Record 3 of Set 13 | kavaratti
# Processing Record 4 of Set 13 | maria aurora
# Processing Record 5 of Set 13 | barcelona
# Processing Record 6 of Set 13 | naze
# Processing Record 7 of Set 13 | ishigaki
# Processing Record 8 of Set 13 | yerbogachen
# Processing Record 9 of Set 13 | paramonga
# Processing Record 10 of Set 13 | dunedin
# Processing Record 11 of Set 13 | gornopravdinsk
# Processing Record 12 of Set 13 | saint anthony
# Processing Record 13 of Set 13 | dutse
# Processing Record 14 of Set 13 | eresos
# Processing Record 15 of Set 13 | santiago del estero
# Processing Record 16 of Set 13 | booue
# Processing Record 17 of Set 13 | kargasok
# Processing Record 18 of Set 13 | berekua
# Processing Record 19 of Set 13 | verkhoyansk
# Processing Record 20 of Set 13 | bubaque
# Processing Record 21 of Set 13 | thanh hoa
# Processing Record 22 of Set 13 | tomatlan
# Processing Record 23 of Set 13 | marabba
# Processing Record 24 of Set 13 | aksarka
# Processing Record 25 of Set 13 | gazojak
# Processing Record 26 of Set 13 | huangmei
# Processing Record 27 of Set 13 | ust-nera
# Processing Record 28 of Set 13 | lincoln
# Processing Record 29 of Set 13 | kasongo
# Processing Record 30 of Set 13 | villa oliva
# City not found. Skipping...
# Processing Record 31 of Set 13 | linxia
# Processing Record 32 of Set 13 | khandyga
# Processing Record 33 of Set 13 | hay river
# Processing Record 34 of Set 13 | buala
# Processing Record 35 of Set 13 | labuhan
# Processing Record 36 of Set 13 | nyurba
# Processing Record 37 of Set 13 | bremerton
# Processing Record 38 of Set 13 | lata
# Processing Record 39 of Set 13 | laiwu
# Processing Record 40 of Set 13 | moissala
# Processing Record 41 of Set 13 | sao raimundo nonato
# Processing Record 42 of Set 13 | novobirilyussy
# Processing Record 43 of Set 13 | susangerd
# Processing Record 44 of Set 13 | yartsevo
# Processing Record 45 of Set 13 | barguzin
# Processing Record 46 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 13 | stokmarknes
# Processing Record 48 of Set 13 | hami
# Processing Record 49 of Set 13 | ostrovnoy
# Processing Record 50 of Set 13 | trat
# Processing Record 1 of Set 14 | punta cardon
# Processing Record 2 of Set 14 | tateyama
# Processing Record 3 of Set 14 | kahului
# Processing Record 4 of Set 14 | odate
# Processing Record 5 of Set 14 | scalloway
# City not found. Skipping...
# Processing Record 6 of Set 14 | chalus
# Processing Record 7 of Set 14 | kuching
# Processing Record 8 of Set 14 | robertson
# Processing Record 9 of Set 14 | mansa
# Processing Record 10 of Set 14 | riyadh
# Processing Record 11 of Set 14 | ganta
# Processing Record 12 of Set 14 | newton
# Processing Record 13 of Set 14 | newport
# Processing Record 14 of Set 14 | sinuapa
# Processing Record 15 of Set 14 | ebolowa
# Processing Record 16 of Set 14 | anadyr
# Processing Record 17 of Set 14 | batemans bay
# Processing Record 18 of Set 14 | kamenka
# Processing Record 19 of Set 14 | evensk
# Processing Record 20 of Set 14 | bontang
# Processing Record 21 of Set 14 | marsh harbour
# Processing Record 22 of Set 14 | tezu
# Processing Record 23 of Set 14 | totskoye
# Processing Record 24 of Set 14 | jalu
# Processing Record 25 of Set 14 | port hardy
# Processing Record 26 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 27 of Set 14 | raposa
# Processing Record 28 of Set 14 | avera
# Processing Record 29 of Set 14 | tessalit
# Processing Record 30 of Set 14 | gigmoto
# Processing Record 31 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 32 of Set 14 | araouane
# Processing Record 33 of Set 14 | ust-maya
# Processing Record 34 of Set 14 | qaqortoq
# Processing Record 35 of Set 14 | bukachacha
# Processing Record 36 of Set 14 | temozon
# Processing Record 37 of Set 14 | barra do garcas
# Processing Record 38 of Set 14 | mehamn
# Processing Record 39 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 14 | ikalamavony
# Processing Record 41 of Set 14 | coahuayana
# Processing Record 42 of Set 14 | marion
# Processing Record 43 of Set 14 | marquette
# Processing Record 44 of Set 14 | tazovskiy
# Processing Record 45 of Set 14 | tabuk
# Processing Record 46 of Set 14 | bela
# Processing Record 47 of Set 14 | mingaora
# Processing Record 48 of Set 14 | kropotkin
# Processing Record 49 of Set 14 | kostomuksha
# Processing Record 50 of Set 14 | bloomfield
# Processing Record 1 of Set 15 | umm lajj
# Processing Record 2 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 15 | sinnamary
# Processing Record 4 of Set 15 | ugoofaaru
# Processing Record 5 of Set 15 | tevaitoa
# Processing Record 6 of Set 15 | bodden town
# Processing Record 7 of Set 15 | henties bay
# Processing Record 8 of Set 15 | natchez
# Processing Record 9 of Set 15 | guachucal
# Processing Record 10 of Set 15 | urucara
# Processing Record 11 of Set 15 | yantongshan
# Processing Record 12 of Set 15 | mackay
# Processing Record 13 of Set 15 | uige
# Processing Record 14 of Set 15 | inhambane
# Processing Record 15 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 15 | nabire
# Processing Record 17 of Set 15 | kaseda
# Processing Record 18 of Set 15 | miri
# Processing Record 19 of Set 15 | sehithwa
# Processing Record 20 of Set 15 | jumla
# Processing Record 21 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 15 | nanticoke
# Processing Record 23 of Set 15 | plerin
# Processing Record 24 of Set 15 | tottori
# Processing Record 25 of Set 15 | maxixe
# Processing Record 26 of Set 15 | yulara
# Processing Record 27 of Set 15 | matara
# Processing Record 28 of Set 15 | ous
# Processing Record 29 of Set 15 | lingao
# Processing Record 30 of Set 15 | bayji
# Processing Record 31 of Set 15 | magaria
# Processing Record 32 of Set 15 | tres arroyos
# Processing Record 33 of Set 15 | evans
# Processing Record 34 of Set 15 | chicama
# Processing Record 35 of Set 15 | saucillo
# Processing Record 36 of Set 15 | floriano
# Processing Record 37 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 15 | kalispell
# Processing Record 39 of Set 15 | shellbrook
# Processing Record 40 of Set 15 | balykshi
# Processing Record 41 of Set 15 | lalmohan
# Processing Record 42 of Set 15 | los llanos de aridane
# Processing Record 43 of Set 15 | port hedland
# Processing Record 44 of Set 15 | bure
# Processing Record 45 of Set 15 | chunoyar
# Processing Record 46 of Set 15 | darnah
# Processing Record 47 of Set 15 | awjilah
# Processing Record 48 of Set 15 | wonthaggi
# Processing Record 49 of Set 15 | novoagansk
# Processing Record 50 of Set 15 | nazas
# Processing Record 1 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 16 | sinjai
# Processing Record 3 of Set 16 | garowe
# Processing Record 4 of Set 16 | igrim
# Processing Record 5 of Set 16 | victor harbor
# Processing Record 6 of Set 16 | aasiaat
# Processing Record 7 of Set 16 | chaiya
# Processing Record 8 of Set 16 | aloleng
# Processing Record 9 of Set 16 | anqing
# Processing Record 10 of Set 16 | moss vale
# Processing Record 11 of Set 16 | paamiut
# Processing Record 12 of Set 16 | maldonado
# Processing Record 13 of Set 16 | groningen
# Processing Record 14 of Set 16 | tanda
# Processing Record 15 of Set 16 | kerema
# Processing Record 16 of Set 16 | meadow lake
# Processing Record 17 of Set 16 | ondorhaan
# City not found. Skipping...
# Processing Record 18 of Set 16 | pueu
# Processing Record 19 of Set 16 | lokosovo
# Processing Record 20 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 16 | khudumelapye
# Processing Record 22 of Set 16 | byron bay
# Processing Record 23 of Set 16 | randfontein
# Processing Record 24 of Set 16 | mayo
# Processing Record 25 of Set 16 | nizhniy ufaley
# Processing Record 26 of Set 16 | jiwani
# Processing Record 27 of Set 16 | khasan
# Processing Record 28 of Set 16 | vao
# Processing Record 29 of Set 16 | caxito
# Processing Record 30 of Set 16 | brigantine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 717

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hobart -42.8794  147.3294     59.05        55          75
# 1  Punta Arenas -53.1500  -70.9167     46.51        53          75
# 2   Clyde River  70.4692  -68.5914      1.08        83          94
# 3         Airai  -8.9266  125.4092     72.66        56          69
# 4         Vaini -21.2000 -175.2000     78.96        83          20
# 5      Thompson  55.7435  -97.8558     26.76        93          90
# 6       Salalah  17.0151   54.0924     84.29        23           0
# 7        Shingu  33.7333  135.9833     67.19        57          43
# 8     Busselton -33.6500  115.3333     74.28        56           1
# 9      Khatanga  71.9667  102.5000    -27.47       100          90
#
#    Wind Speed Country   Current Weather
# 0        4.00      AU     broken clouds
# 1       18.41      CL     broken clouds
# 2        4.05      CA   overcast clouds
# 3        5.14      TL     broken clouds
# 4        9.22      TO        few clouds
# 5        3.44      CA        light snow
# 6       12.66      OM         clear sky
# 7        3.09      JP  scattered clouds
# 8       11.41      AU         clear sky
# 9        2.01      RU   overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
